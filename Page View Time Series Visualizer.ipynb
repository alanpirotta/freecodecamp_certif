# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv('fcc-forum-pageviews.csv', index_col='date', parse_dates=True)

# %%
df.head()
# Out:
#             value
# date
# 2016-05-09   1201
# 2016-05-10   2329
# 2016-05-11   1716
# 2016-05-12  10539
# 2016-05-13   6933

# %%
df.info
# Out:
# <bound method DataFrame.info of              value
# date
# 2016-05-09    1201
# 2016-05-10    2329
# 2016-05-11    1716
# 2016-05-12   10539
# 2016-05-13    6933
# ...            ...
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-02  220144
# 2019-12-03  158549
#
# [1304 rows x 1 columns]>

# %%
# Clean data
# df = None
df = df[(df['value'] > df['value'].quantile(0.025)) & (df['value'] < df['value'].quantile(0.975))]

# %%
plt.figure(figsize=(15,5))
plt.title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
plt.ylabel('Page Views')
plt.plot(df, color='red')

# %%
df2 = pd.DataFrame([0,0,0,0], columns=['value'], index=['2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01'])
df.append(df2)
# Out:
#                       value
# 2016-05-19 00:00:00   19736
# 2016-05-26 00:00:00   18060
# 2016-05-27 00:00:00   19997
# 2016-05-28 00:00:00   19044
# 2016-05-29 00:00:00   20325
# ...                     ...
# 2019-12-03 00:00:00  158549
# 2016-01-01                0
# 2016-02-01                0
# 2016-03-01                0
# 2016-04-01                0
#
# [1242 rows x 1 columns]

# %%
df = df.reset_index()
df['year'] = df['date'].dt.to_period('Y')
df['month'] = df['date'].dt.strftime('%m')
df = df.set_index('date')
df
# Out:
#              value  year month
# date
# 2016-05-19   19736  2016    05
# 2016-05-26   18060  2016    05
# 2016-05-27   19997  2016    05
# 2016-05-28   19044  2016    05
# 2016-05-29   20325  2016    05
# ...            ...   ...   ...
# 2019-11-24  138875  2019    11
# 2019-11-29  171584  2019    11
# 2019-11-30  141161  2019    11
# 2019-12-01  142918  2019    12
# 2019-12-03  158549  2019    12
#
# [1238 rows x 3 columns]

# %%
# df['month'] = df['month'].replace({'01':'January',
#                         '02':'February',
#                         '03':'March',
#                         '04':'April',
#                         '05':'May',
#                         '06':'June',
#                         '07':'July',
#                         '08':'August',
#                         '09':'September',
#                         '10':'October',
#                         '11':'November',
#                         '12':'December'})
# df

# %%
df_bar= df.groupby(['year','month']).mean().reset_index()
df_bar
# Out:
#     year month          value
# 0   2016    05   19432.400000
# 1   2016    06   21875.105263
# 2   2016    07   24109.678571
# 3   2016    08   31049.193548
# 4   2016    09   41476.866667
# 5   2016    10   27398.322581
# 6   2016    11   40448.633333
# 7   2016    12   27832.419355
# 8   2017    01   32785.161290
# 9   2017    02   31113.071429
# 10  2017    03   29369.096774
# 11  2017    04   30878.733333
# 12  2017    05   34244.290323
# 13  2017    06   43577.500000
# 14  2017    07   65806.838710
# 15  2017    08   47712.451613
# 16  2017    09   47376.800000
# 17  2017    10   47438.709677
# 18  2017    11   57701.566667
# 19  2017    12   48420.580645
# 20  2018    01   58580.096774
# 21  2018    02   65679.000000
# 22  2018    03   62693.774194
# 23  2018    04   62350.833333
# 24  2018    05   56562.870968
# 25  2018    06   70117.000000
# 26  2018    07   63591.064516
# 27  2018    08   62831.612903
# 28  2018    09   65941.733333
# 29  2018    10  111378.142857
# ...

# %%
plt.figure(figsize=(15,15))
sns.barplot(x=df_bar['year'], y=df_bar['value'], hue=df_bar['month'], palette='hls')
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %%
def draw_line_plot():
    # Draw line plot





    # Save image and return fig (don't change this part)
    fig.savefig('line_plot.png')
    return fig

def draw_bar_plot():
    # Copy and modify data for monthly bar plot
    df_bar = None

    # Draw bar plot





    # Save image and return fig (don't change this part)
    fig.savefig('bar_plot.png')
    return fig

def draw_box_plot():
    # Prepare data for box plots (this part is done!)
    df_box = df.copy()
    df_box.reset_index(inplace=True)
    df_box['year'] = [d.year for d in df_box.date]
    df_box['month'] = [d.strftime('%b') for d in df_box.date]

    # Draw box plots (using Seaborn)





    # Save image and return fig (don't change this part)
    fig.savefig('box_plot.png')
    return fig
